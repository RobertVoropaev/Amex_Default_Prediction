# %%
# %load_ext autoreload
# %autoreload 2

import gc
import warnings

import scipy as sp
import numpy as np
import pandas as pd
import pickle
from collections import defaultdict
import random
import os

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from catboost import CatBoostClassifier
from sklearn.decomposition import PCA

import sys
sys.path.append("..")
from src import *

warnings.filterwarnings('ignore')
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
class CFG:
    n_folds = 5
    
    only_one_iter = True
    
    feature_selection_step1 = True
    
    model_params = {
        'iterations': 1000000,
        'learning_rate': 0.03,
    #     "l2_leaf_reg": 3, 
    #     "random_strength": 1,
    #     "bagging_temperature": 1,
    #     "max_depth": 6,
    #     "one_hot_max_size": 2, 
#         "rsm": 1,
        'loss_function': "Logloss",
        'use_best_model': True,
        "eval_metric": "Logloss",
        "early_stopping_rounds": 1000,
        'task_type': 'GPU'
    }
    
    
    seed = SEED
    seed_list = [111]
    
seed_everything(CFG.seed)

# %%
features = AmexFeatures()

# %% [markdown]
# ## Donwload

# %%
# %%time
train = pd.read_parquet("../tmp/train_agg.parquet")
test = pd.read_parquet("../tmp/test_agg.parquet")
print(train.shape)
# Out:
# (458913, 4448)
# CPU times: user 35.3 s, sys: 38 s, total: 1min 13s
# Wall time: 36.6 s

# %%
if CFG.feature_selection_step1:
    with open("../tmp/selected_features_step1.pickle", "br") as f:
        cols = pickle.load(f)
    train = train[["customer_ID", "target"] + cols]
    test = test[["customer_ID"] + cols]
print(train.shape)
# Out:
# (458913, 2765)

# %%
train["fold"] = np.random.randint(low=0, high=CFG.n_folds, size=train.shape[0])

# %%
cat_features = features.get_categorical(train)
train[cat_features] = train[cat_features].astype(np.int8)
test[cat_features] = test[cat_features].astype(np.int8)

# %%
prediction = np.zeros(test.shape[0])
amex_metric_score = 0
logloss_score = 0
iterations = 0

for fold in range(0, CFG.n_folds):
    if CFG.only_one_iter and fold != 0:
        break
    print(f" Fold {fold} ".center(80, "="))
    
    X_train, X_val = train[train["fold"] != fold], train[train["fold"] == fold]
    
    y_train = X_train["target"]
    X_train = X_train.drop(["customer_ID", "target", "fold"], axis=1)

    y_val = X_val["target"]
    X_val = X_val.drop(["customer_ID", "target", "fold"], axis=1)
    
    for seed in CFG.seed_list:
        print(f" Seed {seed} ".center(80, "-"))
        
        cb = CatBoostClassifier(**CFG.model_params, 
                                random_seed=seed)
        cb.fit(
            X = X_train,
            y = y_train,
            eval_set=(X_val, y_val),
            cat_features=cat_features,
            verbose=1000
        )

        cb.save_model(f"../models/cb_fold_{fold}_seed_{seed}.cb_model")

        amex_metric_fold = amex_metric(y_val, cb.predict_proba(X_val)[:, 1])
        amex_metric_score += amex_metric_fold
        logloss_fold = cb.best_score_['validation']['Logloss']
        logloss_score += logloss_fold
        print(f"Fold {fold}, seed: {seed}: amex_metric {amex_metric_fold}, logloss {logloss_fold}")

        pred_fold = cb.predict_proba(test.drop(["customer_ID"], axis=1))[:, 1]
        prediction += pred_fold

        iterations += 1
        
        print()
    
    
amex_metric_score /= iterations
prediction /= iterations
logloss_score /= iterations

print(f"MEAN AMEX METRIC: {amex_metric_score}, LOGLOSS: {logloss_score}")
telegram(f"Train model end: MEAN AMEX METRIC: {amex_metric_score}, LOGLOSS: {logloss_score}")
# Out:
# ==================================== Fold 0 ====================================
# ----------------------------------- Seed 111 -----------------------------------
# 0:	learn: 0.6562541	test: 0.6563657	best: 0.6563657 (0)	total: 109ms	remaining: 1d 6h 16m 12s
# 1000:	learn: 0.2133631	test: 0.2214788	best: 0.2214788 (1000)	total: 1m 29s	remaining: 1d 46m 2s
# 2000:	learn: 0.2033058	test: 0.2199123	best: 0.2199123 (2000)	total: 2m 57s	remaining: 1d 31m 23s
# 3000:	learn: 0.1945715	test: 0.2192444	best: 0.2192444 (3000)	total: 4m 25s	remaining: 1d 28m 11s
# 4000:	learn: 0.1866683	test: 0.2188061	best: 0.2188051 (3997)	total: 5m 53s	remaining: 1d 26m 28s
# 5000:	learn: 0.1793934	test: 0.2186356	best: 0.2186194 (4881)	total: 7m 21s	remaining: 1d 24m 19s
# 6000:	learn: 0.1725556	test: 0.2184451	best: 0.2184374 (5995)	total: 8m 49s	remaining: 1d 21m
# 7000:	learn: 0.1661601	test: 0.2183360	best: 0.2183327 (6985)	total: 10m 17s	remaining: 1d 19m 13s
# 8000:	learn: 0.1601399	test: 0.2183020	best: 0.2182863 (7865)	total: 11m 45s	remaining: 1d 18m 10s
# bestTest = 0.2182862696
# bestIteration = 7865
# Shrink model to first 7866 iterations.
# Fold 0, seed: 111: amex_metric 0.7931035621166074, logloss 0.21828626962106895
#
# MEAN AMEX METRIC: 0.7931035621166074, LOGLOSS: 0.21828626962106895

# %%
agg_imp = defaultdict(int)
feature_imp = defaultdict(int)

drop_features = []

sorted_feature_imp = sorted(zip(cb.feature_importances_, cb.feature_names_), reverse=True)
min_imp = sorted_feature_imp[100][0] * 0.1

for imp, name in sorted_feature_imp:
    agg_imp["_".join(name.split("_")[2:-1])] += imp
    feature_imp["_".join(name.split("_")[:2])] += imp
    print(name, imp)
    if imp < min_imp:
        drop_features.append(name)
# Out:
# P_2_last_3m 8.687045286053307
# B_1_last_3m 3.7899465648942208
# S_3_mean_13m 2.073367247586612
# B_9_last_3m 1.6468220814316394
# D_48_last_3m 1.4768782042773598
# B_2_last_3m 1.4267359463129523
# D_39_last_3m 1.3729682772642087
# R_3_mean_13m 1.3504714114443415
# D_44_last_3m 1.294781069185904
# S_3_last_3m 1.1304371071343529
# D_51_last_3m 0.8577964458884126
# B_4_last_3m 0.8300364103257281
# B_8_first_6m 0.8002885117273382
# D_45_last_3m 0.7572487026477797
# R_1_mean_3m 0.7539765201636645
# D_47_last_3m 0.6727418886164435
# B_4_last_first_diff_13m 0.6561796103961833
# B_3_last_3m 0.5870526736918987
# B_4_last_mean_diff_13m 0.5420905398268688
# D_79_last_3m 0.5365482436651273
# R_1_mean_13m 0.5298927766319265
# B_3_last_first_diff_13m 0.4725132501251758
# R_1_last_3m 0.46085040632870544
# D_43_last_3m 0.4460035425058905
# D_50_last_std_diff_6m 0.44299275641764374
# B_10_mean_3m 0.4342124304240024
# D_56_last_3m 0.42156481077293545
# B_18_last_3m 0.42032807204858413
# D_56_first_13m 0.407577112027594
# D_39_mean_3m 0.406850366245888
# D_50_mean_6m 0.39637253775108355
# B_23_last_3m 0.38876006078234965
# D_65_mean_6m 0.3760987989142107
# B_5_last_3m 0.3715504268183728
# D_39_std_13m 0.3691806225634627
# R_2_last_3m 0.3668620822810505
# D_43_mean_3m 0.363400498360891
# R_27_last_3m 0.35609835507291915
# D_39_std_6m 0.3540219772850251
# P_2_first_13m 0.339224404598995
# B_6_last_std_diff_13m 0.3377271268544707
# D_41_last_mean_diff_13m 0.3255452368133621
# D_41_last_first_diff_13m 0.315429841868682
# P_2_last_std_ratio_6m 0.3126693290326849
# D_121_last_3m 0.27628578812241616
# D_44_last_first_diff_13m 0.27360321076163574
# B_2_mean_3m 0.2727369909960749
# S_7_last_3m 0.25565812543602207
# S_15_mean_13m 0.25141361915273025
# S_8_mean_3m 0.25008019727058883
# R_27_last_std_ratio_13m 0.24852956845845992
# R_1_mean_6m 0.2302125603411124
# B_3_last_mean_diff_13m 0.22842100701736548
# D_50_last_3m 0.22628797175272683
# R_2_mean_3m 0.2213667247221309
# B_4_std_13m 0.22045307568035674
# R_2_last_std_diff_6m 0.2191917399056898
# D_52_last_3m 0.2106338978792564
# R_3_last_3m 0.20323290972446853
# B_3_std_6m 0.20114466232509082
# R_5_last_3m 0.19078904619832343
# D_79_last_mean_diff_13m 0.18907067508935613
# D_44_std_13m 0.18859765576252008
# R_2_last_std_diff_13m 0.1845335028875271
# D_59_last_3m 0.16326126057205298
# B_26_last_3m 0.1602781107639248
# D_50_last_std_diff_3m 0.16024402061231485
# D_65_last_3m 0.15864076180740302
# D_51_first_3m 0.15819231165620795
# B_3_std_13m 0.15765664761132833
# B_6_last_std_ratio_6m 0.15650696225233723
# D_119_first_13m 0.1535630629358761
# S_15_mean_6m 0.15348684728330317
# D_44_last_mean_diff_13m 0.15247669609454592
# D_62_last_3m 0.14966604437561967
# B_9_first_3m 0.148163808181802
# B_14_last_3m 0.14438965905523507
# D_131_last_3m 0.13946244883043052
# B_8_first_13m 0.13850816556551848
# D_62_first_13m 0.13777960171298842
# D_43_first_13m 0.1377078284564847
# B_5_mean_3m 0.13719625284768844
# D_41_last_first_diff_6m 0.1368242220220936
# B_23_std_13m 0.1348939928404204
# D_120_last_13m 0.1343472510004988
# D_46_first_13m 0.1307264328808232
# D_65_mean_3m 0.1290289375261341
# D_41_std_3m 0.12859047777474905
# S_12_mean_13m 0.12559967886936288
# B_26_mean_3m 0.1253470955837072
# D_53_last_6m 0.1250791833818539
# D_52_first_6m 0.12340232571647773
# D_39_last_mean_diff_6m 0.12297055041087682
# D_50_mean_13m 0.12267704029241422
# D_39_last_first_diff_3m 0.12040602292299782
# B_4_last_first_diff_6m 0.11833366387747955
# D_61_mean_13m 0.1182786951004479
# D_75_std_13m 0.11483231188617193
# D_46_last_std_diff_3m 0.11210121290163104
# D_52_first_13m 0.10520480709272892
# S_11_first_13m 0.1031006849977992
# S_11_mean_3m 0.10243442967563117
# D_105_first_13m 0.10131564988078971
# D_48_last_mean_ratio_3m 0.10123563072159383
# D_123_first_13m 0.09861618671080463
# D_75_first_13m 0.09810923149918287
# D_75_last_3m 0.0968354725034369
# D_55_last_first_diff_13m 0.09605712592493519
# D_54_last_std_ratio_3m 0.09591261188626467
# P_2_last_first_ratio_13m 0.09587027463184643
# B_9_last_first_diff_3m 0.09527385512421382
# S_12_std_13m 0.09462777772584174
# D_39_std_3m 0.09434960644477111
# D_112_last_std_ratio_6m 0.09415347160180575
# D_124_last_3m 0.09352063115125851
# S_9_mean_13m 0.09344979126185786
# D_41_std_6m 0.09334983437174497
# D_55_last_3m 0.09176565447870244
# P_3_mean_13m 0.09106811971419922
# D_48_last_mean_diff_6m 0.09040679706260518
# B_40_std_13m 0.08725443713143892
# S_5_first_13m 0.08668341015758788
# D_61_last_std_ratio_13m 0.08662060423548434
# B_23_last_mean_diff_13m 0.08575438568576449
# D_59_first_13m 0.0853333578836975
# D_59_std_13m 0.08490967631068866
# D_39_mean_6m 0.08435172473236802
# D_66_last_13m 0.08423108830392556
# D_41_last_3m 0.08408447168082331
# B_9_last_mean_diff_3m 0.0839713684584481
# D_62_first_3m 0.08299116598436794
# D_61_last_3m 0.08269160683684194
# D_50_first_6m 0.0820706200565043
# B_10_mean_6m 0.08061323436442112
# D_112_last_std_ratio_13m 0.0803064905427705
# D_122_last_3m 0.0793225275395354
# B_25_first_3m 0.0785664497037303
# D_66_last_3m 0.07824376431897721
# S_27_mean_13m 0.07586803402139833
# D_44_last_std_ratio_6m 0.07538156706752644
# D_48_last_std_ratio_6m 0.07511891898093197
# B_17_first_13m 0.0749741041871249
# R_21_mean_13m 0.07420805169544016
# B_1_first_6m 0.07319208782499571
# B_33_mean_3m 0.07308777467202268
# B_26_mean_13m 0.07251518922432644
# B_4_last_std_ratio_3m 0.07245824059292577
# R_3_first_13m 0.0719486529016455
# D_133_std_13m 0.07150278997653743
# D_65_std_3m 0.07115894695417307
# D_48_first_3m 0.07098118527512216
# R_11_last_3m 0.0709000161554785
# B_4_first_6m 0.06958882189547407
# R_2_last_std_diff_3m 0.06853928225643821
# S_5_mean_13m 0.0683293718065161
# D_48_first_6m 0.06788932145216096
# B_9_first_13m 0.06742311657802937
# D_123_last_first_diff_13m 0.06741570189603119
# B_4_first_13m 0.06723701276490378
# S_3_first_3m 0.06685670602363256
# R_2_last_mean_diff_13m 0.06661952981820952
# B_22_mean_3m 0.0665116893325894
# D_66_last_6m 0.06607821180214797
# S_22_first_6m 0.06585964613698869
# D_44_first_13m 0.06559632682742503
# D_46_last_mean_ratio_6m 0.06511885645282954
# D_39_last_first_diff_6m 0.06493519458317454
# B_1_last_first_diff_13m 0.06470052680709056
# D_55_last_std_ratio_6m 0.06413528668082549
# D_51_first_6m 0.06399630380879656
# D_39_last_first_diff_13m 0.06396116300565835
# D_48_first_13m 0.06377282225516204
# B_6_last_std_diff_6m 0.06347475626151607
# B_4_std_6m 0.06339132585660216
# B_25_last_3m 0.06296643841222985
# D_62_first_6m 0.0629620612948619
# D_59_std_6m 0.062473575696166336
# B_9_last_first_diff_13m 0.062170009462974296
# D_47_last_mean_ratio_13m 0.061782290327262374
# S_9_last_3m 0.061493064657612055
# B_13_first_3m 0.06144166487883426
# S_22_last_3m 0.06139856255671208
# D_79_first_13m 0.06133690912498675
# B_10_first_6m 0.060985731186173335
# R_11_mean_13m 0.06094768094563969
# D_79_last_first_diff_13m 0.060826319811545806
# B_17_mean_6m 0.06056971870050649
# B_9_std_13m 0.06045150518897024
# D_60_last_3m 0.0604064660536266
# R_8_mean_3m 0.06039253704280717
# B_23_std_6m 0.05992988041203336
# B_6_first_13m 0.05957659660141521
# S_9_first_13m 0.05946041497597159
# B_20_first_13m 0.05943077798375654
# D_121_last_std_ratio_13m 0.059325560180428616
# D_74_std_6m 0.059323276031928024
# B_11_last_std_ratio_6m 0.0591292145178877
# D_133_last_3m 0.05896619142035328
# B_17_std_6m 0.05892272334576771
# D_54_last_std_ratio_6m 0.05871600802029208
# D_74_last_std_ratio_6m 0.05866493298589001
# B_10_first_3m 0.05864328375970995
# D_58_last_std_ratio_13m 0.05851253732822303
# D_41_std_13m 0.058270233288147136
# D_70_mean_13m 0.05772413918830633
# D_48_last_mean_diff_13m 0.057678445963403935
# B_10_last_3m 0.057661683611995314
# R_5_std_13m 0.05702380221929977
# B_40_last_std_ratio_13m 0.056826610658176055
# D_72_first_3m 0.056612765650209666
# B_22_last_mean_diff_13m 0.05658714129314449
# B_1_last_first_diff_3m 0.05644329431621678
# B_9_last_mean_diff_13m 0.056053960561863306
# B_17_last_std_ratio_3m 0.05604456975033426
# P_3_std_13m 0.05603370382486608
# S_13_std_13m 0.05595138163910079
# S_9_mean_3m 0.05569791640035063
# B_22_last_std_diff_3m 0.05556754656132511
# B_22_last_std_ratio_13m 0.055064660291575133
# D_44_last_std_ratio_3m 0.05468877904842086
# D_80_last_mean_diff_13m 0.05452145258954234
# S_5_last_mean_diff_3m 0.05441842299963236
# D_61_first_13m 0.054322675750490296
# D_119_last_3m 0.05416192588301544
# D_48_last_mean_diff_3m 0.05393709843313231
# B_18_first_3m 0.05392936710688569
# B_3_last_std_ratio_3m 0.053808014882673644
# R_4_mean_3m 0.053775192710587894
# B_23_first_3m 0.05336142121831653
# B_4_first_3m 0.05297719821698616
# B_22_std_6m 0.0528970125861725
# P_2_last_mean_ratio_13m 0.052885809586902664
# D_91_last_std_diff_3m 0.05272167845239766
# B_40_mean_13m 0.05259500312436
# D_120_last_6m 0.0524434717175617
# D_58_first_6m 0.052366725535936194
# D_77_first_13m 0.05219548370800949
# B_3_last_mean_diff_3m 0.05218799836199016
# B_9_first_6m 0.051995419618632785
# B_23_last_std_ratio_6m 0.05194393252786118
# B_20_last_3m 0.051869914571565555
# B_4_last_first_diff_3m 0.05182535393397532
# D_70_std_6m 0.051664801007119565
# B_3_last_std_ratio_6m 0.05150124535620741
# B_9_std_3m 0.051458527441677976
# D_145_last_mean_diff_13m 0.051147939115978154
# B_3_first_13m 0.051027700880928256
# D_39_last_std_diff_3m 0.05094854751037653
# B_22_last_std_ratio_3m 0.05065754098604631
# P_3_first_13m 0.05057108538564227
# D_114_last_3m 0.05048034801224189
# D_47_last_first_ratio_13m 0.05026517904123332
# B_16_last_first_diff_6m 0.05019099727832803
# B_3_first_6m 0.05003808988969891
# D_121_last_mean_ratio_13m 0.050019502902645445
# R_1_last_mean_diff_13m 0.05001943108495881
# S_15_std_13m 0.049968762535170914
# B_40_last_std_ratio_3m 0.04987023203239635
# B_3_last_mean_diff_6m 0.04971832425492315
# D_51_last_mean_ratio_13m 0.049621983812730926
# B_8_last_3m 0.0495441447316205
# S_11_first_6m 0.04950630388574263
# D_61_first_3m 0.04944725083126235
# D_54_mean_13m 0.04942727029966085
# D_55_first_13m 0.04937252634331278
# D_55_last_std_ratio_3m 0.049087540014797044
# B_16_first_13m 0.04897478846352964
# D_145_last_3m 0.048838638328411586
# S_8_last_3m 0.04877786503995345
# D_145_last_first_diff_13m 0.048776351788554814
# B_40_first_13m 0.048674024123038485
# R_20_last_3m 0.04866181068333995
# B_19_last_std_ratio_3m 0.04843172175648677
# D_44_first_6m 0.04835353590757888
# R_1_last_std_diff_13m 0.048344055646478236
# D_112_mean_3m 0.048029937171007314
# B_19_std_13m 0.047836189699036864
# D_59_last_first_diff_13m 0.04772987950590235
# D_70_std_13m 0.047706184915444524
# B_4_last_std_ratio_6m 0.04759731211324645
# D_54_last_3m 0.047392253278293044
# D_61_first_6m 0.047283984101739056
# D_58_last_3m 0.047177972326986076
# R_16_mean_13m 0.04716460107912527
# B_28_last_first_diff_13m 0.046844134936409335
# D_140_last_std_ratio_3m 0.04680423848669999
# B_20_last_std_ratio_3m 0.04678726719385814
# B_40_first_6m 0.04653894927788215
# P_4_first_13m 0.046528617685166564
# B_1_first_3m 0.046468018200164316
# D_72_mean_13m 0.046410518008986004
# B_20_last_mean_diff_3m 0.046348285831990264
# B_1_last_mean_diff_13m 0.046335553735004066
# S_27_std_6m 0.046134365009561695
# D_51_std_13m 0.04611965282880706
# B_4_last_mean_diff_6m 0.046041147702503664
# B_9_std_6m 0.04572263601381005
# B_18_first_6m 0.045698556864223486
# R_10_last_std_diff_13m 0.045694246575461755
# B_1_last_mean_diff_3m 0.045370702643025285
# D_112_mean_13m 0.045206874735379494
# B_11_last_std_ratio_3m 0.04516204886806018
# S_7_mean_13m 0.04514723739442305
# B_2_std_6m 0.04506318836879738
# D_59_last_std_ratio_13m 0.045006171028807274
# B_17_last_std_ratio_13m 0.044837436982030555
# R_5_mean_3m 0.04481250037401642
# S_27_first_13m 0.044774925411470885
# R_16_mean_3m 0.04468698391906333
# D_44_first_3m 0.04460804936394536
# D_112_last_std_ratio_3m 0.04441750943155595
# B_9_last_first_diff_6m 0.044341701783984236
# R_3_last_mean_diff_6m 0.04433583767291514
# D_52_last_first_diff_13m 0.04430570017289173
# S_5_last_std_ratio_6m 0.044300749147675435
# B_19_last_mean_diff_3m 0.044227146906261894
# D_61_last_std_diff_13m 0.044190854108101994
# D_52_last_std_ratio_6m 0.04411945670252499
# B_19_last_3m 0.044060107199034144
# S_13_last_first_diff_13m 0.043981939521272294
# B_26_std_3m 0.043941988377837
# S_8_std_13m 0.04390155603592442
# B_19_last_std_ratio_6m 0.04380838065872818
# D_61_std_13m 0.04380443604106498
# D_72_first_6m 0.04374838084737799
# B_22_last_3m 0.043656083961949546
# D_48_last_first_diff_6m 0.043502288487443475
# B_16_last_std_ratio_6m 0.043460748960399566
# B_25_last_std_ratio_3m 0.043432422063585205
# D_75_last_std_ratio_3m 0.04341447552321642
# D_46_last_3m 0.043355046097768246
# B_23_last_std_ratio_3m 0.04306727707539234
# D_54_mean_6m 0.04290213971107378
# R_11_mean_3m 0.04283544573223319
# B_25_last_std_ratio_6m 0.042728851954330384
# B_9_last_mean_diff_6m 0.04272216448213425
# D_66_first_3m 0.042633752675899916
# B_13_first_6m 0.04249568672447392
# B_40_last_mean_diff_13m 0.042482178161433626
# D_46_last_mean_diff_6m 0.04242242430354739
# D_58_last_std_ratio_3m 0.04220295228148783
# B_22_first_13m 0.04215234116504133
# S_11_std_13m 0.042131846102575886
# S_22_mean_13m 0.042098247211281824
# D_59_std_3m 0.04209406453996218
# B_2_last_mean_ratio_3m 0.041970404380302855
# B_19_first_6m 0.041937129080142854
# D_61_last_std_ratio_3m 0.041914498661904
# R_19_first_13m 0.04185202086280299
# B_3_std_3m 0.04169103141565422
# D_79_std_6m 0.041436279447356755
# B_16_last_3m 0.041420793847488056
# B_33_first_6m 0.04141004430984765
# B_6_std_13m 0.04136495221326603
# D_83_first_3m 0.04135065906470268
# S_27_std_13m 0.041331199003444785
# D_124_last_first_diff_13m 0.0412316616782892
# D_43_first_6m 0.04120719911746484
# D_112_last_3m 0.04103335215915537
# B_3_first_3m 0.04094427862471061
# B_22_last_std_ratio_6m 0.04081863356496622
# B_1_last_mean_diff_6m 0.04078848357185124
# D_70_first_6m 0.04078073207343294
# R_15_std_13m 0.04074432994145877
# S_7_first_13m 0.04069478850332015
# S_11_last_3m 0.04066376585419229
# B_28_last_std_ratio_3m 0.040612360470836585
# B_16_last_std_ratio_13m 0.04054671837839593
# B_20_first_6m 0.040436937010217874
# B_33_first_3m 0.040418365315615046
# B_17_mean_13m 0.04036641489347966
# R_15_mean_13m 0.040363247274360185
# B_18_last_first_ratio_6m 0.04031091231169569
# R_2_mean_13m 0.04025482502337971
# B_40_last_std_ratio_6m 0.04024594829223261
# P_3_last_3m 0.040023168694242287
# R_1_last_first_ratio_6m 0.039895158379231084
# S_11_last_mean_ratio_13m 0.03971294179454464
# D_133_first_3m 0.039700117743934206
# D_140_last_3m 0.03952072285184779
# B_3_last_first_diff_3m 0.039476470537613884
# B_28_last_std_ratio_6m 0.03947268477554972
# B_1_last_std_ratio_3m 0.03944217918479084
# B_14_first_3m 0.039406484554268185
# S_12_std_3m 0.0393908019050207
# S_15_first_3m 0.039371917949192696
# R_3_std_13m 0.03934889416446311
# R_10_mean_6m 0.03925199031932612
# D_50_last_std_ratio_3m 0.039221086752591776
# P_4_last_std_ratio_3m 0.03918300301613713
# D_45_last_std_ratio_6m 0.03916300893592815
# D_44_last_mean_diff_6m 0.03911909264292363
# B_20_last_first_diff_3m 0.039062295292838486
# D_48_std_6m 0.039046012863379935
# P_2_last_first_diff_13m 0.03890630020661261
# R_1_last_mean_ratio_13m 0.03885673138135643
# D_48_last_std_ratio_3m 0.03839345664371169
# D_83_last_3m 0.038301211763087706
# B_23_first_13m 0.038297351887822094
# D_51_first_13m 0.03817634681296222
# B_14_first_13m 0.03798646554564094
# D_45_std_13m 0.03794990302928535
# B_6_last_first_ratio_6m 0.037922815436895914
# D_43_std_13m 0.03770572320858887
# B_2_first_13m 0.037637071901983635
# D_114_last_6m 0.03755437137831689
# D_55_last_std_ratio_13m 0.0375151672206588
# D_79_first_3m 0.03745718799555272
# B_1_last_first_diff_6m 0.03736857138394852
# S_7_last_std_ratio_3m 0.03725106501354857
# D_139_last_std_ratio_6m 0.03722793297006068
# D_114_first_13m 0.03721591948848439
# D_43_first_3m 0.03704601566466854
# P_3_mean_3m 0.03699544391023288
# S_3_first_13m 0.036802941243566235
# R_15_mean_3m 0.036674133501448325
# B_3_last_first_diff_6m 0.03654388257242023
# B_19_first_13m 0.03645970263833828
# D_77_first_6m 0.036443013274504145
# R_11_last_std_diff_3m 0.03636157323317493
# D_41_first_13m 0.03626117198649131
# D_133_first_6m 0.03623523265402989
# D_39_first_3m 0.03611307863517504
# B_13_first_13m 0.03611193940106778
# D_55_last_first_diff_3m 0.03600315412293403
# S_22_last_mean_ratio_13m 0.035992384425498146
# S_7_first_6m 0.035969685107661804
# D_58_first_13m 0.03590512540807893
# R_1_last_std_diff_6m 0.03585397489063946
# B_17_last_3m 0.03573968360064805
# B_2_last_mean_ratio_6m 0.03571745205357664
# D_79_std_13m 0.035637945715124235
# B_22_last_first_diff_13m 0.035611555969781376
# D_121_last_first_ratio_13m 0.035577823104614846
# D_45_last_first_ratio_13m 0.035450520463326175
# B_22_std_13m 0.0354047710122912
# D_43_std_6m 0.035379717006083444
# D_52_last_mean_ratio_6m 0.03537614546967812
# B_14_last_first_diff_3m 0.035339969972640405
# R_5_last_std_diff_3m 0.03533404777200819
# B_1_std_13m 0.0352859001928243
# B_40_last_std_diff_3m 0.03525012792868341
# S_13_last_first_diff_6m 0.03504773979008489
# D_139_last_3m 0.034992771816245466
# B_23_last_first_diff_13m 0.034952128948883665
# B_23_last_first_diff_6m 0.034936983219607476
# S_5_std_13m 0.0347060675812173
# B_10_first_13m 0.034615988054921144
# D_46_last_mean_diff_3m 0.03451446267634099
# S_12_mean_6m 0.03449942199591243
# S_22_mean_3m 0.03446640682610751
# B_28_first_6m 0.03440568113736196
# R_10_mean_13m 0.034235251722930654
# D_91_last_std_ratio_6m 0.03422891320516731
# B_19_last_mean_diff_13m 0.034207858693447446
# D_121_last_first_ratio_6m 0.03402488746597556
# B_32_mean_13m 0.0338603691121731
# B_10_last_std_ratio_6m 0.03383272499407813
# R_20_std_6m 0.03382245768175949
# B_6_mean_13m 0.03378704696952784
# D_75_last_std_ratio_6m 0.03372404596195672
# R_10_last_mean_ratio_13m 0.03368296242334216
# R_3_last_first_diff_13m 0.033681370967256354
# D_140_last_std_ratio_13m 0.033671973172131074
# B_5_last_std_diff_13m 0.03354204921595593
# D_102_first_13m 0.03354200247822502
# D_133_last_first_diff_6m 0.03342419225577055
# S_12_last_std_ratio_3m 0.0333991840572244
# B_18_first_13m 0.03336693666418795
# B_28_first_3m 0.033186235907412355
# S_22_last_mean_diff_13m 0.03310582357524772
# B_25_first_6m 0.03291410288980679
# S_12_std_6m 0.0328376660857834
# S_3_first_6m 0.03280779917934973
# D_72_first_13m 0.03270186310232501
# D_61_last_std_ratio_6m 0.03259162589087204
# B_17_first_3m 0.03257569557128336
# B_22_last_mean_diff_6m 0.03253423350209677
# R_1_last_first_ratio_13m 0.03248453780850219
# D_45_last_first_ratio_6m 0.0324573730439558
# D_59_last_std_ratio_3m 0.03243446468731241
# B_33_last_3m 0.03242701449540531
# S_3_std_13m 0.03229766109852721
# D_145_last_std_ratio_6m 0.032270676845567045
# R_1_std_13m 0.032269086645284446
# S_27_first_6m 0.03217793011087826
# D_131_std_13m 0.0320814158915722
# B_23_first_6m 0.03188474291959672
# B_1_first_13m 0.03188373894556392
# D_59_last_std_ratio_6m 0.031781657858012576
# D_133_last_mean_diff_6m 0.031704605269248405
# D_46_last_std_ratio_6m 0.031677656346937984
# B_25_last_std_ratio_13m 0.03167513225790507
# R_21_last_mean_diff_3m 0.031575659383810094
# B_10_mean_13m 0.031573427896260754
# B_20_last_first_diff_13m 0.031462355049335075
# B_1_last_std_ratio_6m 0.031254276374605545
# B_20_last_std_ratio_13m 0.03125317211980765
# D_133_last_mean_diff_3m 0.031236648941503162
# B_18_last_mean_ratio_6m 0.03121696515976487
# D_39_last_mean_ratio_13m 0.0312144016231571
# D_102_last_std_ratio_3m 0.03121316903768157
# B_9_last_std_ratio_3m 0.031147149941440237
# P_3_first_3m 0.03113675911165484
# B_14_first_6m 0.031082367289460705
# D_52_last_first_ratio_13m 0.030987931564337785
# R_8_mean_6m 0.03093077931911712
# D_70_last_first_diff_13m 0.03092492396150018
# B_22_first_6m 0.030893761921345003
# B_19_std_6m 0.03088531028919088
# B_12_first_13m 0.030865160730617486
# B_2_last_first_ratio_3m 0.030775331699080713
# S_24_last_std_ratio_6m 0.030753828373109977
# D_70_last_first_diff_6m 0.030739214864106357
# P_3_mean_6m 0.030732007047364018
# D_52_last_first_ratio_3m 0.030688968085655553
# D_52_last_mean_ratio_13m 0.03065167937734329
# R_10_std_6m 0.030621804769555103
# D_41_mean_13m 0.03057217073900603
# D_133_last_std_diff_3m 0.030540859951836256
# B_19_last_first_diff_13m 0.03053927907427798
# B_14_last_std_ratio_6m 0.030460477882607664
# D_45_last_mean_ratio_13m 0.0303950425444406
# D_54_first_13m 0.03037832882806506
# S_12_last_std_diff_3m 0.03034616721547152
# B_17_first_6m 0.03034146563718627
# D_75_last_std_ratio_13m 0.030330032870324583
# R_1_last_std_ratio_3m 0.030273576090806695
# S_15_first_6m 0.030261702540616633
# S_12_last_mean_diff_13m 0.030251131838471043
# D_45_last_first_ratio_3m 0.03023566488071251
# B_16_last_std_ratio_3m 0.030173188068978958
# R_19_std_6m 0.03008372043375728
# R_11_mean_6m 0.030018634907160117
# B_1_std_6m 0.03000925502290024
# D_53_last_first_ratio_6m 0.029961832042398818
# R_5_mean_13m 0.029925728641117658
# P_2_last_first_ratio_6m 0.02990980737796831
# R_1_last_mean_diff_6m 0.029879244637433945
# D_44_last_mean_diff_3m 0.02984943260557289
# D_130_first_13m 0.029793918701554935
# B_22_last_mean_diff_3m 0.02973661002820596
# B_6_last_mean_ratio_13m 0.02966686707369618
# S_12_first_13m 0.029666856833895115
# D_61_last_mean_diff_3m 0.02961024881613721
# D_129_first_6m 0.029533976741726104
# B_37_last_std_ratio_6m 0.029529279399664862
# D_58_std_13m 0.029477834405489935
# S_22_first_13m 0.029473267430347724
# S_3_std_3m 0.029470302101503833
# D_78_mean_3m 0.02942926902655137
# B_6_last_first_ratio_13m 0.02941737516572078
# P_2_last_mean_diff_3m 0.02941111759312594
# D_84_std_6m 0.02939675837472937
# D_47_last_first_ratio_3m 0.02935374899876581
# B_40_last_mean_diff_3m 0.029352157813249794
# D_140_last_std_diff_3m 0.029350365698980568
# B_12_last_std_ratio_13m 0.029333453099770725
# D_96_mean_13m 0.029285902881862627
# B_19_last_mean_diff_6m 0.02926125320299005
# S_15_first_13m 0.029238332559774035
# D_45_last_std_ratio_3m 0.029136065358095677
# B_23_last_mean_diff_3m 0.02912088950020249
# S_11_first_3m 0.029080782429304695
# B_37_last_std_ratio_3m 0.029025667105598642
# P_2_last_first_diff_3m 0.029022833261395143
# D_141_last_std_ratio_3m 0.029017734809367722
# D_74_last_first_diff_13m 0.028962749233168866
# D_78_mean_13m 0.028929316610368894
# D_39_last_std_ratio_3m 0.028926969279422073
# D_129_last_std_ratio_6m 0.02889410378822197
# D_72_last_std_ratio_13m 0.02887734528428472
# R_1_last_std_diff_3m 0.028835246872360592
# D_44_std_6m 0.028829955223404362
# D_104_last_first_ratio_3m 0.02877893390102899
# R_4_std_13m 0.028722391643038702
# P_2_std_13m 0.028677168870220746
# D_91_first_13m 0.028659152688361778
# D_102_last_first_diff_13m 0.028619521030346064
# D_60_mean_3m 0.028586332987338776
# S_5_first_6m 0.028560187400449043
# B_33_last_first_ratio_6m 0.028557466062848272
# D_80_last_first_diff_13m 0.02851691821497243
# B_6_last_3m 0.02844977986877478
# R_16_last_mean_diff_13m 0.028449300453117398
# S_13_last_3m 0.028298377085382572
# D_48_last_first_diff_3m 0.02829408307430986
# D_58_last_first_ratio_13m 0.02819401642301919
# S_7_first_3m 0.028139403645565098
# D_70_first_13m 0.028093106083861865
# S_7_last_mean_diff_13m 0.028080746823941568
# S_22_last_std_ratio_3m 0.02805495955094661
# B_40_last_first_diff_13m 0.02804698623978426
# B_18_last_std_ratio_6m 0.028009618927919748
# R_2_first_6m 0.027952932270650543
# D_96_std_6m 0.027947722224604437
# B_32_last_std_ratio_13m 0.027920147211403408
# S_3_last_first_diff_13m 0.027872735538158815
# B_10_last_first_ratio_6m 0.027847889311926322
# D_75_std_6m 0.02778059219131264
# R_20_mean_3m 0.02777925127071015
# B_22_std_3m 0.027752924218328482
# S_6_std_13m 0.027750341641806196
# S_12_first_6m 0.027683834517019185
# D_46_last_std_ratio_13m 0.027676396526523626
# D_102_std_6m 0.027666267658714362
# B_40_mean_6m 0.02765548828094001
# D_128_last_first_ratio_13m 0.027646510467192357
# R_19_last_3m 0.027622467593463325
# B_9_last_std_ratio_6m 0.027521132328383786
# R_8_std_3m 0.02750982391395115
# P_3_last_std_diff_3m 0.02750761147499426
# B_32_last_std_ratio_3m 0.027507481124223514
# S_24_last_mean_ratio_13m 0.027446151137701148
# D_78_last_std_diff_3m 0.0274073501164471
# B_9_last_first_ratio_13m 0.02734482137119778
# D_43_last_first_diff_6m 0.02734462781087598
# B_6_mean_3m 0.027317864089173062
# B_6_last_std_diff_3m 0.02729256461686278
# B_2_first_3m 0.027226168950211346
# S_6_mean_3m 0.027216592478504508
# D_79_first_6m 0.02719813134530183
# D_102_last_first_diff_6m 0.027166074147774992
# D_122_first_6m 0.027127383262105113
# D_118_last_first_ratio_13m 0.02709555158288881
# D_47_last_std_ratio_13m 0.027071878925601242
# B_4_last_mean_diff_3m 0.027056615471684583
# B_8_last_std_ratio_6m 0.027052504880146953
# D_131_first_13m 0.027017324850841337
# D_78_mean_6m 0.026963256953541445
# D_70_first_3m 0.02695654431346014
# R_16_std_13m 0.026906053141689104
# D_119_last_first_ratio_13m 0.026856752065710372
# B_3_last_mean_ratio_13m 0.026771551850262382
# B_2_last_mean_ratio_13m 0.026761613770472394
# B_40_last_std_diff_13m 0.026706395957180957
# B_40_last_3m 0.026669665505767767
# D_140_last_mean_diff_13m 0.02665782343252621
# R_1_std_6m 0.02664708945782531
# B_10_last_std_ratio_3m 0.02664052050316641
# D_58_last_mean_diff_13m 0.026615708981316693
# B_6_first_3m 0.02659864374287443
# D_133_last_mean_diff_13m 0.026592292366789217
# S_12_last_mean_ratio_13m 0.02659135720932052
# S_15_mean_3m 0.02655102580700459
# R_10_std_13m 0.026538826134961325
# R_10_std_3m 0.026502654193717775
# B_10_last_std_diff_6m 0.026488202153786375
# D_71_first_13m 0.026404852240401663
# R_3_first_3m 0.026366324339298128
# B_26_std_13m 0.026346953446481424
# R_3_last_std_diff_13m 0.02629968577900171
# B_40_mean_3m 0.026281198689943705
# B_16_last_first_diff_13m 0.02624836864722812
# B_19_last_first_diff_6m 0.026213142689526847
# R_10_mean_3m 0.026184243835007122
# S_15_last_mean_diff_13m 0.026183490929882817
# P_2_last_mean_diff_13m 0.026088818026733653
# B_17_last_mean_diff_6m 0.026071154204085536
# B_6_first_6m 0.026065716346560283
# S_27_first_3m 0.026059341596562563
# D_45_last_mean_ratio_6m 0.02604448634211206
# B_14_last_std_ratio_3m 0.02602020187810851
# D_79_last_first_diff_6m 0.025988531043959595
# B_5_last_std_ratio_13m 0.025964539870968625
# B_33_first_13m 0.025863084746360072
# D_120_last_3m 0.02584612336777952
# D_70_mean_3m 0.025818226460658858
# B_2_first_6m 0.025792142760630826
# S_15_last_first_diff_6m 0.025712024487854812
# B_5_first_6m 0.025686639637334946
# S_24_last_std_ratio_3m 0.025651390579529202
# D_52_last_std_ratio_3m 0.025621577879425796
# S_13_last_std_diff_3m 0.025566779201811753
# B_12_last_mean_ratio_13m 0.025554288433930837
# S_5_last_3m 0.025509196646129453
# B_19_last_first_ratio_13m 0.02549362060562197
# D_48_std_3m 0.025470698733887177
# D_113_std_3m 0.02543993747906743
# S_13_last_mean_ratio_6m 0.025432641320677237
# D_53_last_mean_diff_13m 0.025423573406337698
# S_18_std_13m 0.025408493905749348
# D_46_mean_13m 0.025408066447597893
# B_20_last_std_ratio_6m 0.02536527544694468
# P_4_last_std_ratio_6m 0.025360332105246436
# R_3_std_3m 0.02535671780743382
# B_25_last_mean_diff_3m 0.02535383814253508
# S_7_last_first_diff_13m 0.02531086672087279
# S_8_last_mean_ratio_3m 0.025277117936946883
# R_15_std_3m 0.025242989347941516
# B_22_first_3m 0.025235277506622814
# D_44_last_first_diff_3m 0.025216667918824296
# S_9_last_std_diff_13m 0.02511117109227851
# D_75_std_3m 0.025110659090937962
# R_11_std_3m 0.025085006918695668
# D_58_first_3m 0.025065951626383195
# B_28_last_3m 0.025019197290452464
# D_102_last_first_diff_3m 0.025004564715061715
# D_123_std_13m 0.024983456686750692
# B_20_last_mean_diff_13m 0.024979219391425653
# R_5_std_6m 0.02492194740110794
# D_102_last_mean_diff_3m 0.024820817696729194
# B_5_last_std_ratio_6m 0.024711212311603767
# D_80_first_13m 0.02469841946180701
# R_1_last_first_diff_13m 0.024692645650469195
# R_4_last_mean_diff_13m 0.024656361657015256
# S_27_last_mean_ratio_13m 0.024631242506176
# D_112_std_13m 0.02459941998066867
# B_17_mean_3m 0.024591126199162285
# R_16_std_6m 0.02458434263646357
# D_145_last_std_ratio_3m 0.02453018436180357
# D_128_last_first_ratio_6m 0.024485918973944743
# S_8_last_mean_ratio_13m 0.0244836100469655
# D_72_std_3m 0.02445654789533553
# D_143_last_std_ratio_3m 0.024407910794638617
# R_1_last_std_ratio_6m 0.024388029818971358
# D_123_mean_13m 0.02436319783099812
# B_5_last_mean_ratio_6m 0.02435462369225538
# B_5_std_13m 0.024351155439250743
# D_71_last_first_diff_3m 0.024343320738381684
# D_133_std_3m 0.024284872837888643
# D_53_mean_6m 0.02425607829013733
# D_84_last_std_ratio_3m 0.024220184171596167
# D_43_std_3m 0.024213935085805827
# D_130_last_first_diff_6m 0.024194374877618358
# D_83_last_first_ratio_6m 0.02412473377728354
# D_59_last_mean_diff_13m 0.024097968864426583
# S_15_last_first_diff_13m 0.02407863006154341
# D_96_mean_6m 0.02407443502834262
# B_18_last_mean_ratio_13m 0.02406453369398557
# B_19_last_first_diff_3m 0.02405985599590454
# B_22_last_first_ratio_6m 0.024008968753038446
# R_1_last_first_diff_6m 0.024000589358472837
# D_71_first_6m 0.023991491811663136
# D_78_std_6m 0.0239876695778886
# S_7_last_first_diff_3m 0.023987204076824236
# S_8_last_std_diff_3m 0.023981045091821654
# D_52_last_mean_ratio_3m 0.023956267738524824
# D_74_last_std_ratio_3m 0.02393901329816604
# D_133_first_13m 0.023904080156570483
# D_70_last_std_diff_3m 0.023902647128951463
# R_11_last_mean_ratio_13m 0.023896828510680992
# D_83_last_first_diff_13m 0.023886282807906452
# S_12_mean_3m 0.023886213626656775
# R_11_std_6m 0.02387997854359777
# S_9_last_std_diff_3m 0.023811846417226598
# P_2_std_6m 0.0238019852650048
# R_4_mean_6m 0.02380106993137622
# D_129_last_first_ratio_3m 0.02379403245987825
# D_131_first_3m 0.02378493942709911
# B_26_mean_6m 0.023756307855982484
# B_37_last_mean_ratio_3m 0.023733879325491654
# B_41_std_6m 0.023721525773016658
# D_133_last_std_diff_13m 0.023704489510619497
# S_13_last_first_ratio_6m 0.023622919719441176
# D_129_last_3m 0.023550538793379802
# D_133_last_first_diff_13m 0.023523654782957558
# B_20_last_mean_diff_6m 0.023500822319306672
# D_45_last_mean_ratio_3m 0.023491377754356484
# D_102_last_std_ratio_6m 0.02348664347816911
# D_58_last_std_ratio_6m 0.023452099286363146
# D_60_first_6m 0.023441676453810997
# R_4_last_std_diff_3m 0.023432797764508125
# B_25_first_13m 0.023428657800577863
# D_66_first_6m 0.023421021268670947
# R_1_last_first_ratio_3m 0.02332249252146122
# D_52_last_first_ratio_6m 0.02330381312581594
# S_5_std_6m 0.023291547884207685
# B_20_last_first_diff_6m 0.02327565340166159
# D_86_first_6m 0.023240400904393315
# D_80_first_6m 0.023237430891795877
# B_28_first_13m 0.023235256332845323
# B_3_last_first_ratio_13m 0.023222172353694375
# B_2_last_first_ratio_13m 0.02321826416953241
# B_23_std_3m 0.023215073206503303
# P_2_last_first_ratio_3m 0.023208148873570714
# D_91_std_13m 0.02319979909466612
# R_1_first_6m 0.023177924030494075
# D_50_last_mean_ratio_3m 0.023099597729242614
# B_12_std_13m 0.023098253083926684
# D_117_first_13m 0.023061065507164778
# D_47_last_first_ratio_6m 0.023024068700570374
# S_13_last_mean_diff_13m 0.02299298240001053
# S_22_first_3m 0.022979531403849455
# D_60_first_3m 0.022936332933919217
# D_70_last_mean_diff_13m 0.02293338930573795
# D_44_last_first_diff_6m 0.022918718780007997
# S_13_first_3m 0.02288849970103056
# D_113_last_3m 0.02285664877746877
# D_130_std_6m 0.02285130908916105
# D_72_last_3m 0.022841608599256408
# B_2_last_mean_diff_13m 0.022832598306512707
# S_15_last_3m 0.0228221358767173
# D_75_last_first_diff_3m 0.022810562785091696
# D_114_first_3m 0.02278074028455759
# B_9_last_mean_ratio_6m 0.022759240403339646
# D_70_last_3m 0.022743167415850075
# B_22_last_first_diff_3m 0.022733161403301973
# D_59_last_first_diff_3m 0.02269747271006987
# D_112_last_mean_ratio_6m 0.02266469408089656
# D_78_last_std_ratio_13m 0.02266096268217261
# D_79_last_mean_diff_6m 0.02265414592425964
# D_48_last_first_diff_13m 0.022646545682987664
# D_41_last_std_ratio_6m 0.022607060037227723
# S_12_last_std_diff_13m 0.022596226403850467
# B_12_last_first_ratio_13m 0.022584798310160907
# D_52_last_std_ratio_13m 0.022544519491290736
# P_4_first_6m 0.022543422973588925
# R_4_mean_13m 0.022520393835703117
# D_75_last_first_diff_13m 0.022517317118647143
# B_6_std_6m 0.022514289920138566
# D_55_last_first_ratio_13m 0.022491314688561456
# D_107_first_13m 0.02245291471713882
# D_39_mean_13m 0.022433854121833956
# B_5_last_std_diff_3m 0.02242429363951404
# D_112_last_first_ratio_13m 0.022383855979325285
# B_2_std_3m 0.022361377636583028
# D_58_last_first_diff_13m 0.022359513951102045
# B_28_std_13m 0.02233357744852143
# D_48_std_13m 0.02233317743236655
# P_2_last_mean_ratio_6m 0.022300079301937947
# B_14_last_first_diff_13m 0.02229583954078141
# S_11_last_std_diff_3m 0.022295114575572334
# D_78_last_mean_ratio_3m 0.02228097600196234
# B_40_first_3m 0.022271262970152784
# S_13_last_std_ratio_13m 0.022209619087529466
# D_50_first_3m 0.02219602741275111
# D_83_first_13m 0.022159165721674385
# D_130_last_std_ratio_3m 0.02213783953675144
# B_17_last_mean_diff_3m 0.022127066927585107
# D_91_last_std_diff_13m 0.022052276284877385
# D_104_first_6m 0.02204125062249573
# S_11_last_first_ratio_3m 0.022033383544312616
# D_51_last_mean_diff_13m 0.021977344477705937
# B_14_std_13m 0.021973263473222173
# R_1_last_first_diff_3m 0.021963677178722878
# B_19_std_3m 0.021957783630424124
# D_128_last_std_ratio_6m 0.021941814686080342
# R_11_last_std_ratio_3m 0.021940641402422734
# B_40_last_first_diff_3m 0.021934926244555814
# D_59_last_mean_diff_3m 0.021825286063514582
# R_16_first_13m 0.021742666406277707
# R_3_mean_3m 0.021728326641117308
# S_6_last_first_diff_13m 0.021726369780731555
# R_20_first_3m 0.021718703543487896
# D_39_last_first_ratio_13m 0.021698100844359216
# B_32_std_13m 0.021692937910264873
# D_44_std_3m 0.021608820709276905
# R_1_std_3m 0.02159006350605083
# S_13_first_6m 0.02156768118406678
# D_123_last_std_diff_13m 0.021511107367692087
# B_41_std_13m 0.021486385749689283
# D_122_last_std_ratio_3m 0.0214708415402639
# D_104_last_std_ratio_13m 0.02146951520715403
# D_94_first_3m 0.02146149321071804
# D_54_last_mean_diff_3m 0.021456424531804998
# B_33_last_mean_ratio_3m 0.021452686935449414
# R_5_std_3m 0.021445863663294273
# R_4_std_6m 0.021433634328090465
# D_72_std_13m 0.021355113485102283
# D_129_last_mean_ratio_13m 0.02135358247404877
# R_10_first_13m 0.02132183132673986
# R_11_last_std_diff_13m 0.021320486210221368
# R_21_first_6m 0.021273972398677208
# B_20_std_3m 0.02127111680517126
# D_113_first_6m 0.02121961158402813
# S_5_last_first_diff_13m 0.02120450621441737
# R_2_last_first_ratio_13m 0.02119319201249507
# R_1_last_mean_diff_3m 0.021188250313011043
# D_51_last_std_ratio_3m 0.02118609084662804
# P_4_first_3m 0.021183287173283265
# R_2_first_13m 0.021170967796458294
# D_65_first_6m 0.02115901504631541
# D_50_last_mean_ratio_13m 0.021119104783075007
# D_128_last_3m 0.021113621649623302
# B_10_last_first_ratio_13m 0.021111747776610956
# D_92_first_3m 0.021081210667748585
# D_122_first_13m 0.021072865137009233
# S_6_first_6m 0.021048492541352045
# B_32_first_3m 0.02102961698733682
# B_41_mean_13m 0.02099054148306528
# D_117_last_3m 0.02094252902819018
# R_3_last_mean_diff_3m 0.02092700871340772
# D_41_last_first_ratio_6m 0.020907853797673258
# B_41_last_first_diff_13m 0.020900010111193038
# S_12_last_std_diff_6m 0.02087289523053544
# D_55_last_first_diff_6m 0.02084608043198366
# S_8_first_13m 0.020826141297673968
# D_91_last_first_ratio_6m 0.020819711107806456
# B_33_std_13m 0.020813277689015506
# D_133_last_std_ratio_3m 0.02081022579407012
# B_17_last_first_diff_13m 0.020751749933437518
# S_8_first_3m 0.020727890987219305
# D_115_std_13m 0.02066955018587147
# R_2_std_6m 0.020599722995735693
# B_12_last_3m 0.020599635978670414
# R_2_last_first_diff_13m 0.02059049698467014
# R_1_last_mean_ratio_6m 0.020534013466013065
# R_8_std_6m 0.02052005001627627
# P_2_last_std_ratio_3m 0.020474189243449112
# D_96_std_13m 0.020451478410028454
# D_70_last_mean_diff_6m 0.020448256911569866
# R_15_first_13m 0.020420015214798127
# D_62_last_mean_ratio_13m 0.020417724085192254
# D_83_last_mean_diff_13m 0.020415624976578884
# R_24_last_first_diff_3m 0.020411909513868304
# B_4_std_3m 0.0203431481556721
# B_13_last_3m 0.02033268589003919
# R_11_last_first_diff_13m 0.020288812141310987
# D_131_last_std_ratio_6m 0.020273565987677995
# B_25_std_3m 0.020257407143046954
# D_70_std_3m 0.02025446482082531
# B_10_last_std_diff_13m 0.020247599794594368
# R_21_std_13m 0.020232628294819536
# R_11_first_13m 0.02021378509137615
# D_74_std_3m 0.02020858450964064
# S_12_last_std_ratio_6m 0.020195815088091398
# R_5_mean_6m 0.020161339303552673
# D_74_last_first_diff_6m 0.020156281032507297
# B_41_std_3m 0.02014172776841136
# D_47_last_mean_ratio_3m 0.02008013374253462
# B_14_last_mean_diff_13m 0.020029651066827806
# D_78_first_13m 0.01996216859597275
# R_3_first_6m 0.01996101208052165
# S_8_last_std_ratio_6m 0.019935253665344283
# B_41_last_mean_diff_13m 0.019924497196300274
# D_126_first_13m 0.019907205824905277
# D_80_first_3m 0.019883570332585396
# D_122_first_3m 0.0198803769548923
# S_9_first_3m 0.019854989532414928
# D_70_last_std_ratio_3m 0.019792007068114854
# S_6_last_first_ratio_13m 0.019775590988354824
# B_26_last_std_ratio_3m 0.019745954644409272
# S_13_last_mean_ratio_3m 0.01972267352542056
# D_141_last_std_ratio_6m 0.019668298227075425
# D_41_first_3m 0.019645029496351784
# D_74_last_first_diff_3m 0.019563771766331402
# B_41_last_mean_diff_6m 0.019554364195624056
# D_43_last_std_diff_3m 0.019525886932587028
# D_78_first_6m 0.019507397184651092
# D_55_last_mean_ratio_13m 0.019501957222798044
# D_78_last_3m 0.019500004909973594
# S_22_last_std_diff_3m 0.019469078159705763
# D_78_std_3m 0.01945647471269148
# D_86_std_3m 0.019450128052438825
# B_32_std_3m 0.01944488036652121
# S_27_last_first_ratio_6m 0.019413038591041567
# B_26_last_mean_diff_13m 0.01935106388554224
# S_27_last_first_diff_6m 0.019350304473594544
# D_46_last_std_ratio_3m 0.019342282529956557
# R_11_first_3m 0.01931303269188219
# B_22_last_first_ratio_13m 0.019312600838428635
# D_65_last_mean_ratio_13m 0.019308363860535544
# D_65_last_std_ratio_3m 0.019304815961743264
# B_16_last_mean_diff_13m 0.019299600589168027
# D_79_last_std_ratio_3m 0.019288854058845922
# D_139_last_first_diff_3m 0.019258243276042267
# B_33_std_6m 0.01925696585616082
# P_2_last_mean_ratio_3m 0.019255751150044624
# B_14_last_mean_diff_6m 0.01925249186166092
# R_21_last_first_diff_3m 0.019236564533755284
# D_71_first_3m 0.019191879953510415
# B_32_last_std_diff_3m 0.019190888847155647
# D_84_last_std_ratio_6m 0.019179021380309465
# D_107_first_6m 0.01917146896550077
# D_115_last_first_ratio_13m 0.019163743493298333
# D_44_last_first_ratio_6m 0.019090388608240767
# D_107_last_3m 0.019079523691012398
# D_130_last_std_ratio_6m 0.019031899632660623
# D_131_std_3m 0.018982266926903347
# R_1_last_mean_ratio_3m 0.018951957136970378
# R_16_last_mean_ratio_3m 0.018934077014986256
# D_127_last_3m 0.018929796144923676
# D_122_last_first_ratio_3m 0.018929739004868235
# D_128_last_first_ratio_3m 0.01891408784965442
# B_32_first_13m 0.01888633499035673
# S_27_mean_6m 0.01886825541807315
# B_5_last_first_diff_6m 0.01886328030379053
# D_123_mean_6m 0.01884349429767667
# R_15_mean_6m 0.018833738562937782
# S_15_last_std_diff_3m 0.018805695535262512
# R_3_std_6m 0.018800661820738307
# D_125_last_first_diff_13m 0.01877237613659899
# D_125_first_13m 0.01876702146280377
# S_22_last_std_ratio_13m 0.018743985289556644
# P_4_last_first_diff_13m 0.018730415209826292
# P_3_last_first_ratio_13m 0.018720291922261382
# D_140_last_first_diff_6m 0.01870688610053316
# D_45_std_3m 0.018703829715495387
# B_2_last_first_ratio_6m 0.018690165436601583
# D_44_last_first_ratio_3m 0.01862907461817565
# D_143_last_std_ratio_6m 0.018627437965486212
# R_16_last_std_ratio_6m 0.01862575919233349
# D_53_last_first_ratio_13m 0.018622514146160955
# D_62_last_first_ratio_3m 0.018600942442434654
# S_8_last_first_diff_13m 0.018598451200739288
# R_5_last_std_ratio_6m 0.018566813160203897
# P_4_last_first_ratio_13m 0.018552676457121157
# D_112_last_first_diff_13m 0.01852306469104426
# S_12_first_3m 0.018516487986799984
# B_33_last_std_diff_3m 0.01851251933506093
# D_41_last_mean_ratio_3m 0.018512378837408618
# B_8_last_std_ratio_3m 0.01850558574276051
# D_83_std_6m 0.01848773366640976
# D_133_last_first_ratio_6m 0.018486288703473606
# D_47_last_std_ratio_3m 0.01847565146114854
# R_27_last_first_ratio_13m 0.018474992791235476
# D_71_mean_3m 0.018474729751201496
# B_12_last_first_ratio_6m 0.01847200101089041
# B_10_last_first_diff_6m 0.01846457022172408
# R_11_last_first_ratio_3m 0.018459351851931077
# S_6_last_std_diff_6m 0.01845488867294883
# D_81_first_13m 0.018412076162572507
# S_27_last_first_diff_13m 0.018397358167755642
# D_125_first_3m 0.018394661632092666
# D_112_last_first_diff_6m 0.01838306625949833
# D_41_last_first_ratio_13m 0.018358585473937216
# D_47_last_mean_ratio_6m 0.01835173481720907
# D_47_last_std_ratio_6m 0.0183496404429005
# B_10_last_std_diff_3m 0.018343332808942195
# D_55_last_first_ratio_6m 0.018331512759578145
# S_18_last_first_ratio_6m 0.018297836591478087
# B_6_last_mean_ratio_3m 0.018292153288030785
# R_10_last_first_diff_13m 0.018280905379819523
# B_40_last_first_diff_6m 0.01825250066400243
# R_2_std_13m 0.018250543019236065
# S_5_last_std_ratio_13m 0.018234124430389183
# B_26_first_13m 0.01823038512442491
# D_51_last_first_ratio_6m 0.018224358138242625
# D_92_mean_3m 0.018210394969064483
# B_7_last_std_ratio_3m 0.018191105747806087
# D_71_std_3m 0.018168314842788386
# S_3_std_6m 0.0181649750976204
# D_91_last_first_diff_13m 0.018143202879156002
# B_26_std_6m 0.018134627589693253
# D_84_mean_6m 0.018125449738810216
# D_86_last_first_diff_13m 0.018094300452671148
# D_50_last_mean_diff_13m 0.018037798088371807
# B_14_last_mean_ratio_13m 0.01797207257580782
# D_39_last_std_ratio_13m 0.017964117191580274
# B_41_last_3m 0.017945743426449157
# S_13_mean_3m 0.01794041661926246
# D_122_last_std_ratio_6m 0.017934885861898547
# R_24_std_13m 0.017903266103650884
# D_104_last_mean_diff_6m 0.017828950361549172
# R_11_std_13m 0.017779365510446066
# D_84_std_13m 0.017753046214208083
# D_39_last_std_ratio_6m 0.017749608102437062
# R_11_last_std_ratio_6m 0.01769890827761468
# D_44_last_first_ratio_13m 0.017680091977244038
# D_112_first_6m 0.017675075752580663
# B_5_first_3m 0.017668982273149992
# D_107_last_first_ratio_3m 0.017665614331260248
# B_33_last_first_diff_13m 0.017661058104929996
# D_65_last_std_diff_6m 0.01765195641652395
# R_4_last_std_diff_13m 0.01764729841333173
# S_13_first_13m 0.017627247976033752
# D_55_std_6m 0.017611107505014035
# D_75_last_mean_diff_13m 0.017610612244272746
# S_5_mean_6m 0.01760775838246746
# S_5_first_3m 0.01756948757431041
# B_25_last_mean_ratio_3m 0.01754387753762868
# D_112_std_6m 0.01753152605244937
# S_27_mean_3m 0.0175273508474137
# D_122_last_mean_ratio_3m 0.017496073374469876
# D_46_first_3m 0.017472762796383597
# D_78_last_first_diff_13m 0.017471360386551994
# R_19_last_std_ratio_13m 0.017459760296537254
# R_8_std_13m 0.017453289510637036
# D_51_std_6m 0.017451044414612957
# D_81_last_first_diff_6m 0.017448367179206677
# D_124_last_first_ratio_13m 0.017437151236809802
# D_124_last_std_ratio_13m 0.017430108782173215
# D_46_last_mean_diff_13m 0.01742910215717886
# P_4_std_13m 0.01742204896575913
# R_16_first_3m 0.017420066591046102
# B_26_last_mean_ratio_13m 0.01740604973732215
# R_8_mean_13m 0.017379828469149
# D_84_first_3m 0.017358440453555637
# D_53_first_13m 0.01735058571384422
# D_91_mean_3m 0.017350504273093603
# D_123_first_6m 0.01732005137207803
# R_11_last_first_ratio_13m 0.017303757840182787
# D_121_last_mean_ratio_6m 0.017284924033134776
# D_127_mean_3m 0.017280767329826353
# D_140_first_3m 0.01727727404961534
# P_4_std_3m 0.017253309115522645
# R_10_last_first_ratio_13m 0.017238687588038048
# D_80_last_std_ratio_3m 0.017226704678824308
# R_16_std_3m 0.017199663184634215
# D_54_last_first_diff_13m 0.017175303466478047
# R_4_last_first_diff_13m 0.017172330319114002
# P_4_last_3m 0.017153157504032714
# S_8_last_first_ratio_3m 0.017124384394585503
# S_13_last_std_ratio_3m 0.017098037467047907
# R_27_last_std_ratio_6m 0.017080562436103983
# R_4_first_3m 0.01706703062075771
# B_22_last_first_diff_6m 0.01706428188317711
# D_121_last_first_diff_6m 0.01705900701120051
# D_129_last_std_ratio_3m 0.017021248368964934
# B_38_first_6m 0.017018201804171032
# D_41_last_first_diff_3m 0.017014287775651643
# B_41_last_first_ratio_13m 0.017014262560408184
# D_105_std_6m 0.016988786942254867
# S_13_last_first_ratio_13m 0.016962212464386024
# S_15_std_6m 0.016958030222404986
# D_91_first_3m 0.016948475068774567
# D_65_last_first_ratio_6m 0.01693833316458033
# R_24_last_first_ratio_13m 0.016937877986227437
# B_8_std_13m 0.016926317252650272
# D_41_last_std_ratio_3m 0.016917595537282972
# S_9_last_first_diff_13m 0.016909558284946773
# D_46_last_first_diff_6m 0.016907673321946124
# D_121_last_first_diff_3m 0.01690751551885372
# D_112_last_mean_diff_6m 0.016906721003769328
# D_130_last_3m 0.016899302973758273
# D_129_last_first_ratio_13m 0.01689894712560051
# R_16_last_mean_diff_6m 0.0168975604025519
# B_26_last_first_diff_6m 0.016885742959925856
# D_60_last_std_ratio_6m 0.016837446411589494
# R_21_std_3m 0.016832493233147658
# B_20_last_mean_ratio_13m 0.016799891982408024
# S_15_last_std_ratio_13m 0.01679151102413574
# D_81_mean_13m 0.01678539558757512
# R_20_first_6m 0.016775362988321177
# D_115_std_3m 0.016761251772320757
# B_5_std_6m 0.016749194229802523
# S_12_last_first_ratio_6m 0.016734878065852235
# D_86_std_13m 0.016723650860977074
# D_47_last_first_diff_13m 0.01671693899034135
# R_20_mean_6m 0.016705780382796798
# B_40_last_mean_diff_6m 0.01670258865221208
# B_12_last_std_ratio_3m 0.01669428672222059
# D_46_mean_6m 0.016673599140611735
# B_8_last_mean_diff_6m 0.016672008781179304
# D_131_last_first_ratio_3m 0.016666146045865637
# B_23_last_first_diff_3m 0.016646165909965704
# D_112_last_first_diff_3m 0.01664374315887826
# B_13_last_first_ratio_3m 0.016640538159703032
# R_10_last_first_diff_6m 0.01662306794236557
# B_2_last_std_ratio_3m 0.01662006945963804
# S_18_first_3m 0.016605074444577508
# D_105_first_6m 0.01656764393891706
# S_22_last_std_diff_6m 0.016567596438720977
# D_120_first_13m 0.016567494397395202
# D_104_last_3m 0.01656143892700509
# S_5_last_first_ratio_6m 0.016557648183561056
# D_72_last_std_ratio_6m 0.01654337423849405
# R_16_last_first_ratio_6m 0.016529027689038786
# D_60_std_13m 0.016522171437466183
# R_1_first_3m 0.016513785708929637
# D_128_std_13m 0.01650655691571442
# B_32_std_6m 0.01649134753822982
# B_33_last_std_ratio_3m 0.01646726787515801
# B_6_mean_6m 0.016444833261032476
# R_19_first_6m 0.01643858537802792
# S_5_last_first_diff_3m 0.016425522248130483
# S_15_last_first_ratio_13m 0.016413823628999583
# D_104_last_first_diff_3m 0.01640504705446463
# S_12_last_first_ratio_13m 0.016400564770683832
# B_17_last_std_diff_3m 0.016391041487125058
# B_25_last_mean_diff_13m 0.016365387994606774
# D_129_last_first_diff_13m 0.01635399100465683
# B_26_last_first_ratio_13m 0.01635325534567158
# B_33_std_3m 0.01634926128133611
# R_2_mean_6m 0.016340711293290948
# B_11_last_first_ratio_13m 0.016303877927879972
# D_50_first_13m 0.016292054939709102
# D_112_last_mean_ratio_13m 0.016258069188732932
# D_55_std_3m 0.016253255080064786
# D_130_last_first_ratio_13m 0.01622868689109842
# S_24_last_first_ratio_3m 0.016215441120231253
# D_130_last_mean_diff_3m 0.01621432683347552
# D_72_last_mean_diff_13m 0.016197273808232996
# B_2_last_first_diff_13m 0.01618803373676858
# B_26_last_std_ratio_6m 0.016170087036886344
# B_1_last_mean_ratio_6m 0.016120436110746966
# D_128_last_mean_diff_6m 0.016101594338111484
# D_123_last_mean_ratio_6m 0.016099612704261343
# D_55_std_13m 0.016092803471602884
# D_124_last_first_ratio_6m 0.016089384544986377
# R_11_last_mean_diff_3m 0.01608863992770816
# D_71_last_mean_diff_3m 0.016080408615882832
# D_107_last_std_ratio_6m 0.01607595835655396
# S_5_std_3m 0.016075220107482757
# D_78_last_std_diff_6m 0.016058084826704472
# S_11_last_mean_ratio_6m 0.016050179109623926
# R_24_std_3m 0.01602188528495221
# R_11_last_first_ratio_6m 0.015991524886091894
# D_39_last_std_diff_6m 0.015973821866442982
# D_123_std_3m 0.015955417224550097
# D_65_last_first_diff_6m 0.015942014713778388
# R_21_last_mean_ratio_13m 0.015939214650287883
# D_41_last_mean_ratio_13m 0.01593852229308679
# D_58_last_mean_diff_3m 0.015923017209020708
# R_27_last_first_ratio_6m 0.015921835740355484
# D_118_last_std_ratio_6m 0.015915900552615592
# S_7_last_mean_diff_6m 0.015908274340063373
# R_2_last_first_ratio_3m 0.0159038798792495
# D_50_std_13m 0.015901074459954187
# R_27_last_mean_ratio_13m 0.015864009998032384
# D_139_last_first_ratio_3m 0.015863154729247562
# B_26_last_mean_diff_3m 0.015851252801726164
# D_65_first_13m 0.01584620442850043
# B_20_last_first_ratio_13m 0.01582812839349467
# D_61_std_3m 0.01581585663034426
# D_121_last_first_ratio_3m 0.015810523784234504
# D_131_last_first_diff_3m 0.015806251852805115
# D_46_last_mean_ratio_3m 0.015797449480294976
# S_3_last_mean_diff_13m 0.01579123896870009
# D_71_last_std_ratio_6m 0.015788527086441753
# D_124_last_mean_diff_13m 0.015782165412556986
# S_24_last_mean_ratio_3m 0.015754887974341217
# B_33_last_first_diff_6m 0.015751368580737675
# D_47_last_mean_diff_6m 0.01569288581628795
# D_102_last_mean_diff_13m 0.015690619200625002
# D_71_last_first_diff_6m 0.015675178503122663
# S_6_std_3m 0.015669518609688245
# D_62_last_mean_ratio_3m 0.015668211432283072
# D_60_last_mean_ratio_13m 0.01562377568055724
# B_33_last_first_ratio_13m 0.015618084180210661
# R_20_first_13m 0.015616176204191111
# S_27_last_first_ratio_3m 0.015609368743583424
# D_43_last_std_diff_13m 0.015583131186222472
# D_118_last_first_ratio_3m 0.015569504858376925
# R_2_last_std_ratio_13m 0.015567589454560632
# R_15_first_6m 0.015555811591648356
# B_28_std_6m 0.01553617666489197
# D_114_first_6m 0.015521995552649359
# ...
# R_27_last_mean_diff_3m 0.005930018204225164
# D_118_last_mean_ratio_6m 0.005922358498426161
# D_102_first_3m 0.0059183130401548505
# D_74_last_mean_ratio_3m 0.00590812734220562
# R_15_last_first_ratio_3m 0.005905615793926908
# B_26_last_mean_diff_6m 0.005901352351281523
# D_65_last_first_diff_3m 0.005898753983317441
# D_122_last_first_diff_13m 0.005884131151749344
# D_130_last_mean_ratio_13m 0.00588341068221634
# R_11_last_mean_ratio_6m 0.005880684935120223
# D_81_last_first_ratio_6m 0.005879577356905713
# R_21_first_13m 0.005871418862318577
# D_105_last_std_ratio_3m 0.005861617953295066
# R_27_last_mean_diff_6m 0.005858801803357336
# D_119_last_mean_diff_13m 0.005844823778624771
# D_56_last_std_ratio_13m 0.0058341107452074565
# D_46_std_6m 0.005829564789454365
# D_50_last_mean_diff_6m 0.005829395036554886
# D_53_last_first_diff_13m 0.005812072651024271
# R_2_last_mean_ratio_6m 0.005809059552756659
# B_13_last_mean_diff_13m 0.005792737388881794
# D_125_last_first_ratio_6m 0.005779635337474034
# S_8_last_mean_diff_6m 0.005762600333440398
# D_81_last_std_ratio_6m 0.005760763880769945
# B_11_last_first_ratio_3m 0.005759328678612019
# D_54_std_6m 0.0057554159151347066
# D_94_last_first_ratio_3m 0.005743168568924668
# D_56_last_mean_ratio_3m 0.005730649869301419
# B_13_last_first_diff_6m 0.005729352661713787
# B_16_last_mean_ratio_6m 0.005726531706879396
# D_77_last_std_ratio_6m 0.005696702352965661
# B_40_last_first_ratio_6m 0.005682394041655324
# D_125_last_std_diff_6m 0.005681829966319851
# D_86_last_mean_ratio_3m 0.005680022328172072
# B_18_std_3m 0.005670768445090743
# D_96_last_first_ratio_6m 0.005662626604537004
# D_119_last_first_ratio_6m 0.005658704270330918
# S_12_last_mean_ratio_3m 0.005657423402638122
# R_24_first_6m 0.005656603638351494
# D_94_last_mean_diff_13m 0.005653467129367096
# R_4_last_mean_ratio_6m 0.005645273319408935
# D_65_last_mean_diff_3m 0.0056195288363907895
# R_4_first_6m 0.005612768383041757
# D_84_last_std_diff_3m 0.0056099997882709295
# D_107_last_mean_ratio_13m 0.00560722154755157
# R_20_last_mean_ratio_6m 0.005593144725305856
# S_27_last_std_diff_3m 0.00558579856487495
# D_58_last_mean_ratio_13m 0.0055810937571223376
# D_72_last_mean_ratio_6m 0.005579795527927895
# D_104_last_first_diff_6m 0.005576611842328459
# R_11_last_mean_diff_6m 0.00557509931199785
# D_125_last_mean_ratio_3m 0.00556952765998654
# R_8_last_mean_ratio_6m 0.005558010836297107
# D_91_last_mean_diff_3m 0.005545812979586296
# D_92_last_first_diff_13m 0.005537193218275647
# S_18_last_std_ratio_6m 0.005534790083786953
# D_86_last_std_ratio_6m 0.00552754919808382
# B_19_last_mean_ratio_6m 0.0055172211624020685
# D_107_last_std_ratio_3m 0.005510457530699676
# R_15_last_mean_diff_6m 0.005501697328269169
# R_10_last_std_diff_6m 0.0054840382272770055
# D_46_last_first_ratio_13m 0.005478956527041658
# D_62_last_first_diff_6m 0.005476615942080428
# D_94_last_mean_ratio_13m 0.005458678648706883
# D_77_last_mean_ratio_6m 0.005457287613292768
# D_60_last_first_diff_3m 0.00543881631800136
# R_20_last_mean_diff_6m 0.005426871913892638
# R_19_last_mean_diff_3m 0.005405364388532511
# D_125_last_mean_diff_6m 0.0054022338448132395
# D_124_last_mean_diff_6m 0.0053939010111013624
# P_4_last_mean_ratio_6m 0.005393145678005468
# S_12_last_mean_diff_6m 0.005391446940027171
# D_127_last_std_ratio_13m 0.005381242580708439
# S_3_last_first_ratio_3m 0.0053747858672897626
# D_71_last_3m 0.005340531468837414
# D_122_last_first_diff_6m 0.005336472780258884
# B_16_last_first_ratio_6m 0.005327280420285662
# B_6_last_first_diff_3m 0.005302006713122274
# D_102_last_mean_diff_6m 0.00529510722690904
# D_129_std_3m 0.005283835907187436
# B_6_last_mean_diff_6m 0.005275489862923148
# B_1_last_first_ratio_6m 0.005270768650401831
# D_130_last_mean_diff_13m 0.005267356471367386
# B_14_last_mean_ratio_6m 0.005266482677480321
# B_9_last_first_ratio_3m 0.005256850745412908
# D_61_last_mean_ratio_3m 0.005254963278835281
# D_115_last_3m 0.005252624838313124
# B_4_last_mean_ratio_13m 0.005252027300225623
# S_18_last_first_diff_13m 0.0052486041548479405
# D_77_std_3m 0.005246625064397869
# B_28_last_mean_ratio_3m 0.005245498153911621
# R_24_last_mean_diff_3m 0.00520420131454144
# B_32_last_mean_ratio_13m 0.005203015643217448
# B_20_last_first_ratio_6m 0.005202003845164161
# S_18_std_3m 0.005200083774336304
# R_19_last_mean_diff_13m 0.005195396039500211
# B_23_last_mean_ratio_13m 0.005188628684725046
# B_12_last_mean_diff_13m 0.005165637217714361
# R_15_last_first_diff_6m 0.0051652340588014736
# D_125_last_first_diff_3m 0.005144059109654284
# D_47_last_first_diff_3m 0.005106426726769331
# D_71_last_first_ratio_3m 0.005091408334062596
# D_92_last_mean_ratio_13m 0.005059339434248702
# R_20_last_std_diff_3m 0.005058369466170703
# S_11_last_std_ratio_6m 0.0050389308051990425
# R_10_last_first_diff_3m 0.005038304340986505
# R_27_last_first_diff_3m 0.005031984435757972
# R_15_last_first_ratio_6m 0.005026172722802793
# D_50_last_std_diff_13m 0.005023712203340847
# D_60_last_mean_diff_3m 0.005015705035516995
# D_86_last_std_ratio_3m 0.00501543591806285
# S_8_last_mean_diff_3m 0.004993671254400728
# D_62_last_first_diff_13m 0.004988732121581707
# D_129_last_mean_ratio_6m 0.004985804827213331
# D_129_std_6m 0.004980978460036621
# B_10_last_mean_diff_13m 0.004954306426466242
# D_113_last_mean_ratio_3m 0.004951418379775927
# S_15_last_first_ratio_3m 0.0049497960323443965
# D_62_last_first_ratio_13m 0.00494180710811323
# D_125_last_std_diff_13m 0.0049339311252175515
# D_52_last_mean_diff_6m 0.0049072596904706925
# R_19_last_first_ratio_13m 0.0048963474966282694
# D_123_last_std_ratio_3m 0.004896109300804874
# D_43_last_first_ratio_13m 0.004893841809118125
# R_8_last_first_diff_13m 0.00488929399117159
# D_103_last_first_ratio_13m 0.00487298897571679
# D_94_last_std_ratio_3m 0.004869960907904184
# B_8_last_mean_ratio_3m 0.004837925648595824
# D_91_last_mean_ratio_3m 0.004828912194153476
# R_20_last_first_ratio_3m 0.004827689313201246
# R_15_last_first_diff_13m 0.004803819585201191
# D_122_last_first_ratio_6m 0.0048004919748196595
# D_84_last_mean_ratio_6m 0.004790695720379092
# B_20_last_mean_ratio_6m 0.0047906830327904045
# R_5_last_first_diff_3m 0.004787368366326044
# B_32_last_mean_diff_6m 0.0047863611990215035
# D_113_std_6m 0.00477045584083477
# S_3_last_mean_ratio_3m 0.004765374993526695
# S_7_last_std_ratio_13m 0.004759873149219862
# P_3_last_mean_ratio_6m 0.004730893831264735
# D_127_last_mean_ratio_3m 0.0047251137068883954
# D_56_std_3m 0.004715853138836867
# R_24_last_mean_ratio_13m 0.004708160855085044
# D_129_last_mean_diff_13m 0.0046812581349979735
# D_125_last_std_diff_3m 0.004673501961571936
# D_72_last_mean_ratio_3m 0.0046720306210139935
# B_28_last_first_ratio_6m 0.004671049867377153
# D_43_last_first_diff_3m 0.004663899857687663
# D_81_last_mean_ratio_13m 0.004652890370483751
# B_16_last_first_ratio_3m 0.004636940373392097
# D_119_last_mean_diff_6m 0.0046207555035334595
# D_54_last_mean_diff_13m 0.004589420853416743
# B_3_last_mean_ratio_3m 0.004586479436998618
# R_20_last_mean_ratio_3m 0.004558317508926602
# B_28_last_first_ratio_3m 0.004554042152983577
# B_19_last_first_ratio_3m 0.0045363099416112305
# D_123_last_mean_diff_13m 0.004535610207148544
# D_94_last_std_diff_6m 0.004523404307397298
# D_52_last_first_diff_3m 0.004521474045755352
# B_23_last_first_ratio_3m 0.004514330744492909
# D_103_last_mean_ratio_6m 0.004500340197470173
# R_10_last_mean_ratio_3m 0.004480647494860026
# D_62_last_mean_diff_13m 0.004471079752602165
# D_107_last_mean_ratio_3m 0.004467045561614244
# D_115_last_first_diff_6m 0.0044634014253551015
# S_22_last_first_diff_3m 0.004463199509248179
# D_123_last_mean_diff_6m 0.004456697158863801
# D_96_last_std_ratio_6m 0.004445338698501926
# D_50_last_std_ratio_6m 0.0044333735520334944
# S_8_last_first_diff_3m 0.0044296612097751535
# R_21_last_std_ratio_6m 0.0044258587694062075
# D_127_last_first_diff_13m 0.0044216089722032455
# B_41_last_mean_ratio_6m 0.004380867124384184
# P_4_last_first_ratio_6m 0.004377691545346546
# S_7_last_mean_ratio_13m 0.004366184519785489
# B_32_last_first_ratio_3m 0.00434239006091368
# B_8_std_6m 0.004331732903165201
# D_92_last_std_diff_3m 0.004325671747740223
# S_6_last_mean_ratio_6m 0.004315999070730836
# D_120_first_6m 0.00429704141004076
# D_139_last_mean_ratio_6m 0.004276735397884478
# R_8_last_first_ratio_3m 0.00427164512498529
# R_20_last_std_diff_6m 0.004268015814501038
# D_56_last_mean_ratio_6m 0.004263433127653438
# P_3_last_first_ratio_6m 0.004262823639449471
# R_10_last_first_ratio_3m 0.004253142810703084
# D_145_last_first_diff_3m 0.0042420585682630884
# R_19_last_first_ratio_6m 0.004225713290680555
# R_8_last_mean_diff_6m 0.004223993670406055
# R_15_last_mean_ratio_6m 0.004215184392532434
# D_113_last_mean_ratio_6m 0.004193814113149472
# D_54_last_first_ratio_3m 0.00416826916771283
# R_15_last_mean_ratio_3m 0.0041677892466286965
# B_4_last_mean_ratio_3m 0.004166954752231363
# D_86_last_first_ratio_13m 0.004151764775149033
# R_15_last_mean_diff_3m 0.0041328132417574074
# D_131_last_mean_diff_6m 0.0041193148944455174
# D_145_last_mean_ratio_6m 0.004078260700052284
# D_56_std_13m 0.004072066094254111
# D_115_last_first_ratio_6m 0.004048395665689407
# B_12_last_first_diff_6m 0.0040103179961406546
# R_19_std_3m 0.0040061648799286625
# R_21_last_mean_ratio_3m 0.003968556805009219
# D_68_first_3m 0.003933949140018826
# D_125_std_6m 0.003926119376493963
# D_123_last_std_diff_6m 0.003912464804137284
# S_22_last_mean_diff_3m 0.003898277785136843
# S_9_last_first_ratio_6m 0.003888101097627928
# D_92_last_mean_ratio_6m 0.0038847718037257296
# D_96_last_first_diff_3m 0.00387529811212576
# D_77_last_first_ratio_3m 0.003873454577230366
# D_94_last_mean_diff_6m 0.0038572847777550425
# B_3_last_first_ratio_3m 0.0038537334954968617
# D_96_last_mean_diff_13m 0.003844718477880968
# B_13_last_mean_diff_3m 0.0038073396516162044
# D_51_last_first_diff_3m 0.003801285818604956
# D_140_last_mean_diff_3m 0.0037945273599012948
# R_8_last_first_diff_6m 0.0037944368352210173
# D_104_last_mean_diff_13m 0.003762623392221821
# D_116_first_3m 0.0037549572374312046
# D_91_last_mean_ratio_6m 0.003751881904783412
# D_113_last_first_ratio_3m 0.003745196631612885
# R_10_last_std_diff_3m 0.003740471102747546
# D_59_last_mean_ratio_3m 0.0036916979198249192
# D_77_last_mean_diff_3m 0.00366673410880179
# D_71_last_std_diff_6m 0.0036360060348871767
# D_118_last_first_ratio_6m 0.003634820903316297
# B_41_last_mean_ratio_13m 0.0036100955180637857
# R_8_last_mean_ratio_13m 0.0036026907852040424
# S_22_last_mean_diff_6m 0.00359877223755491
# D_47_last_first_diff_6m 0.0035835364478744606
# D_104_last_mean_ratio_6m 0.0035824951248551802
# D_86_last_std_ratio_13m 0.003572840041276975
# B_25_last_first_diff_3m 0.0035570079627552454
# D_96_last_first_diff_13m 0.0035549010808442016
# D_75_last_first_ratio_6m 0.0035515528502706502
# B_32_last_mean_ratio_3m 0.003548394343467487
# D_115_last_mean_ratio_3m 0.0035476533513271705
# S_9_last_std_ratio_3m 0.0035177801853588397
# D_74_last_mean_ratio_6m 0.003516956301499045
# D_96_last_mean_ratio_13m 0.00351341191536128
# D_119_last_first_diff_6m 0.003507255340366697
# D_92_last_mean_diff_3m 0.00350138435968198
# R_8_last_first_ratio_6m 0.0034881925424127477
# D_94_std_6m 0.003486385750150427
# R_5_last_mean_diff_6m 0.003481912688595773
# D_62_last_first_diff_3m 0.003464936523444237
# D_96_last_mean_ratio_6m 0.0034620717027687704
# B_25_last_mean_diff_6m 0.0034610504283207905
# D_126_first_3m 0.0034433898337796367
# D_133_last_std_ratio_13m 0.003434448996047629
# R_19_last_mean_diff_6m 0.003409758142188491
# B_20_last_mean_ratio_3m 0.0034092664235187806
# D_96_last_std_ratio_3m 0.00340702823087944
# D_105_last_mean_diff_13m 0.0033709275154043604
# D_74_last_first_ratio_6m 0.003366864366015355
# D_105_last_mean_ratio_6m 0.0033640469236467982
# S_9_last_mean_ratio_6m 0.0033397963615883802
# R_16_last_3m 0.0033269433521793653
# R_8_last_mean_diff_3m 0.0033231565724493183
# D_72_last_first_diff_3m 0.0033227152222355416
# B_8_last_mean_ratio_13m 0.0033206123631901153
# D_140_last_mean_ratio_6m 0.0033142870555150127
# R_3_last_mean_ratio_13m 0.0032954243137252514
# R_4_last_mean_diff_3m 0.0032858288304804476
# B_28_last_mean_ratio_6m 0.0032660891321156273
# B_7_last_first_ratio_13m 0.00323584106325361
# R_5_last_mean_ratio_6m 0.003227059021974228
# D_121_last_mean_diff_6m 0.0031946562382037104
# D_61_last_mean_ratio_6m 0.003193519180095969
# B_28_last_mean_ratio_13m 0.003153615666498764
# D_119_last_mean_ratio_6m 0.003128483314883397
# D_58_last_first_ratio_3m 0.003097637510705485
# D_115_last_std_ratio_6m 0.003091178131952252
# D_54_last_mean_ratio_3m 0.003011772903257136
# D_125_last_3m 0.00299954381055141
# D_116_last_13m 0.0029992562723554056
# D_125_last_first_diff_6m 0.0029503874117474765
# B_33_last_first_diff_3m 0.002901813944775574
# B_8_last_mean_ratio_6m 0.0028953780617737173
# D_80_last_3m 0.0028850752436065594
# D_77_last_first_diff_13m 0.0028711703551456136
# D_127_last_std_ratio_3m 0.0028684876954473922
# D_125_last_mean_ratio_13m 0.0028312856556639964
# R_8_last_first_diff_3m 0.0027973221998097678
# D_54_last_first_ratio_6m 0.0027912828318337525
# D_70_last_first_ratio_6m 0.002781142657382809
# D_84_last_mean_diff_6m 0.0027660249487618123
# D_75_last_mean_ratio_13m 0.002758552903440151
# D_56_last_first_ratio_13m 0.002713867953821621
# D_58_last_mean_ratio_6m 0.002712712214920737
# D_54_last_first_diff_6m 0.0027060181415565054
# B_30_last_13m 0.002688630533294837
# B_14_last_first_diff_6m 0.002672799269323147
# R_15_last_first_ratio_13m 0.0026227748855205406
# B_4_last_first_ratio_6m 0.0025552302882282693
# D_75_last_mean_ratio_3m 0.0025489348902583034
# D_94_last_std_diff_3m 0.002542165485228644
# B_30_last_3m 0.002533252155507974
# D_104_last_first_ratio_13m 0.0025329482472241515
# P_3_last_mean_diff_13m 0.0024954794809069728
# D_139_std_3m 0.0024779699292890663
# P_3_last_mean_diff_6m 0.0024265369486871496
# D_102_last_mean_ratio_13m 0.002399414904376604
# D_65_last_first_ratio_3m 0.002333624780054097
# D_65_last_mean_ratio_6m 0.0023273090900329555
# D_126_last_3m 0.002316186197332019
# R_24_last_std_ratio_6m 0.0023077105229823373
# D_56_std_6m 0.0022842017488166875
# D_127_last_mean_ratio_13m 0.002261765795869166
# B_4_last_first_ratio_13m 0.0021804278463124853
# D_60_std_3m 0.0021686714822861416
# R_24_last_std_diff_6m 0.0021670792147700985
# B_26_last_std_diff_3m 0.0021471968982313167
# D_105_last_first_diff_13m 0.002132961310306376
# R_21_last_first_ratio_3m 0.002130352417405857
# S_9_std_13m 0.0021297013442832017
# D_55_last_first_ratio_3m 0.0021281109063994177
# B_32_last_mean_ratio_6m 0.00211474931410151
# D_122_last_mean_diff_13m 0.0020874973265489418
# D_116_last_3m 0.002069459407398732
# D_127_last_mean_diff_13m 0.0019083437738828407
# D_77_last_first_diff_3m 0.0019028722332677587
# D_56_last_first_diff_13m 0.001875760649480984
# D_56_last_mean_diff_6m 0.0018112218658213053
# D_126_last_6m 0.001809599944327948
# D_56_last_std_ratio_6m 0.0017460953848579665
# D_77_last_std_ratio_3m 0.0016827860553807836
# R_8_last_mean_ratio_3m 0.0016508305581168386
# B_41_last_first_ratio_3m 0.001632716761128126
# B_5_last_mean_diff_3m 0.0016159696120209067
# B_30_first_13m 0.0015813111724866605
# D_127_last_mean_diff_6m 0.0015706867039281753
# D_123_last_first_diff_6m 0.0015414165480550418
# D_92_last_mean_diff_6m 0.001512090471923725
# D_50_last_first_ratio_6m 0.0014728470457754973
# D_84_last_std_diff_6m 0.0013815005680168145
# D_56_last_first_ratio_6m 0.0012530317808132738
# D_56_last_mean_diff_13m 0.0012320287739345029
# D_50_last_first_ratio_13m 0.0012299312450689203
# D_62_last_mean_diff_6m 0.0011858600827826485
# B_38_last_6m 0.0011775370804218835
# D_116_last_6m 0.00116217299259158
# B_6_last_mean_diff_3m 0.0011259263742419453
# R_20_last_mean_diff_13m 0.0011212302370094346
# D_50_last_mean_ratio_6m 0.0010733235919028036
# B_38_last_13m 0.0010495334237837998
# R_15_last_std_diff_3m 0.001039429973997724
# R_21_last_std_ratio_3m 0.0009766402662457901
# B_26_last_std_diff_6m 0.0009565185988058789
# D_129_last_mean_diff_6m 0.0009472045739376359
# D_104_last_mean_ratio_13m 0.0009169022204289146
# B_4_last_first_ratio_3m 0.0008895313289685151
# D_56_last_std_ratio_3m 0.0008269044185595326
# B_13_last_std_ratio_13m 0.0006587745138035766
# D_68_first_6m 0.0006430623699367724
# D_66_first_13m 9.798137588810984e-06
# R_15_last_std_ratio_3m 0.0
# D_83_last_mean_ratio_6m 0.0
# D_68_last_6m 0.0
# D_68_last_13m 0.0
# D_68_first_13m 0.0
# D_50_std_3m 0.0
# D_139_last_mean_ratio_13m 0.0
# D_126_first_6m 0.0
# D_117_last_6m 0.0
# D_117_last_13m 0.0
# B_23_last_first_ratio_6m 0.0

# %%
len(drop_features)
# Out:
# 941

# %%
with open("../tmp/selected_features_step2.pickle", "bw") as f:
    pickle.dump(drop_features, f)

# %%
sorted(list(agg_imp.items()), key=lambda x: -x[1])
# Out:
# [('last', 33.85711051994908),
#  ('mean', 12.39462485303898),
#  ('first', 11.378914004183184),
#  ('std', 8.655176663146442),
#  ('last_first_diff', 7.619071824552389),
#  ('last_std_ratio', 7.339633920734294),
#  ('last_mean_diff', 6.193308522960362),
#  ('last_first_ratio', 4.700660767725357),
#  ('last_mean_ratio', 4.385507085548708),
#  ('last_std_diff', 3.4759918381612773)]

# %%
sorted(list(feature_imp.items()), key=lambda x: -x[1])
# Out:
# [('P_2', 9.806891566939091),
#  ('B_1', 4.452791675198407),
#  ('S_3', 3.575325173650572),
#  ('D_39', 3.3634667074020235),
#  ('B_4', 2.908811126519955),
#  ('R_1', 2.6239493448074978),
#  ('B_9', 2.6052284060144704),
#  ('D_44', 2.4540328458209246),
#  ('D_48', 2.333654400152248),
#  ('B_3', 2.1914581892280864),
#  ('B_2', 2.1622765839626994),
#  ('R_3', 2.0009730488454287),
#  ('D_50', 1.6672980247452065),
#  ('R_2', 1.483225331911573),
#  ('D_41', 1.3984870233067332),
#  ('D_51', 1.3973704931695161),
#  ('D_43', 1.3120865836287783),
#  ('B_8', 1.1642382901989758),
#  ('D_79', 1.1570856626819102),
#  ('D_45', 1.1119638044479303),
#  ('B_23', 1.0737105312903146),
#  ('B_6', 1.0715277092238444),
#  ('D_47', 1.0380029318637223),
#  ('B_10', 1.035309008416283),
#  ('D_65', 0.9593557545684349),
#  ('D_56', 0.8970490618913017),
#  ('B_5', 0.8730665257148971),
#  ('S_15', 0.8458430776662866),
#  ('B_18', 0.8268164046910526),
#  ('D_52', 0.820746192176459),
#  ('B_22', 0.8053172044486971),
#  ('R_27', 0.7877580538576654),
#  ('B_40', 0.7629283840358579),
#  ('D_61', 0.7407025505418622),
#  ('D_59', 0.729696867345066),
#  ('S_12', 0.7252783057557465),
#  ('B_26', 0.7205896354179951),
#  ('D_46', 0.7128492318062738),
#  ('B_17', 0.6627394502131976),
#  ('S_7', 0.6478456629609745),
#  ('S_8', 0.6390993760975918),
#  ('D_112', 0.6368745093119346),
#  ('D_121', 0.6306575802473183),
#  ('S_5', 0.6264608628400173),
#  ('R_11', 0.6104244430372938),
#  ('S_11', 0.6025069541085322),
#  ('D_62', 0.6004299849152865),
#  ('D_75', 0.5982451016603482),
#  ('R_5', 0.5922003801015288),
#  ('D_133', 0.5881268805858372),
#  ('D_55', 0.5820602496149531),
#  ('S_22', 0.5803779614760886),
#  ('B_19', 0.5706001617856503),
#  ('D_70', 0.5642706589734987),
#  ('B_20', 0.5431444979202681),
#  ('S_27', 0.5398533632876709),
#  ('B_14', 0.5217718062982118),
#  ('S_13', 0.5131697185881606),
#  ('D_54', 0.5085946346629224),
#  ('P_3', 0.5070126304611599),
#  ('D_58', 0.4977244346905235),
#  ('B_25', 0.4930785970383867),
#  ('B_33', 0.4861463979716525),
#  ('R_10', 0.4668580174229202),
#  ('R_16', 0.4639299110815047),
#  ('S_9', 0.4501528711722165),
#  ('D_78', 0.4471458715039764),
#  ('D_123', 0.4457968147427924),
#  ('D_131', 0.4343293771296196),
#  ('D_72', 0.42438845297987043),
#  ('B_16', 0.4125618717099382),
#  ('R_4', 0.39987326683415847),
#  ('B_32', 0.39428467813754864),
#  ('R_21', 0.38992470952429553),
#  ('D_140', 0.38515334456300565),
#  ('D_119', 0.38195760426903036),
#  ('B_28', 0.373813932800828),
#  ('D_91', 0.3636876155561195),
#  ('D_102', 0.3548406031004173),
#  ('R_20', 0.3509867517851581),
#  ('P_4', 0.34844783185752987),
#  ('D_71', 0.34555106926521245),
#  ('D_80', 0.34520029910118477),
#  ('D_84', 0.34090821207417427),
#  ('S_6', 0.3270290066996813),
#  ('D_145', 0.32369357789575026),
#  ('R_15', 0.31845177185162754),
#  ('D_124', 0.31700620515497757),
#  ('D_60', 0.3128570301630456),
#  ('D_122', 0.311776786322349),
#  ('B_13', 0.3116725027081542),
#  ('B_41', 0.30774660713360247),
#  ('D_83', 0.3075250486464232),
#  ('R_8', 0.30673027237303446),
#  ('D_74', 0.30066963963101595),
#  ('D_66', 0.29461763650721046),
#  ('D_53', 0.29430737854781724),
#  ('B_12', 0.2920065599296192),
#  ('D_96', 0.29081248364477363),
#  ('R_19', 0.2883748126869918),
#  ('D_130', 0.28043004657266996),
#  ('R_24', 0.272615348078754),
#  ('D_129', 0.26854952065370086),
#  ('D_128', 0.26833888393095373),
#  ('S_18', 0.26213512190370863),
#  ('D_86', 0.2599806754356029),
#  ('D_81', 0.251752925161576),
#  ('D_105', 0.24522214929575328),
#  ('D_104', 0.2449672084704789),
#  ('D_120', 0.24044292709438386),
#  ('D_92', 0.23882926956079045),
#  ('D_107', 0.22550882561965113),
#  ('D_125', 0.22341129198420734),
#  ('D_127', 0.22136972236111743),
#  ('D_94', 0.21567750742192873),
#  ('D_77', 0.20995486750634962),
#  ('D_113', 0.2090887959886994),
#  ('D_139', 0.20902760101089668),
#  ('D_114', 0.17745380967326654),
#  ('D_115', 0.17583309268219421),
#  ('B_11', 0.16775303073036008),
#  ('S_24', 0.14886124766600342),
#  ('B_37', 0.1413686393745434),
#  ('D_118', 0.11466036681518178),
#  ('D_141', 0.10878071034354403),
#  ('D_143', 0.09709958315432596),
#  ('B_7', 0.07251975021066831),
#  ('D_103', 0.06912583341263313),
#  ('D_117', 0.06240530801872003),
#  ('B_38', 0.050891110239691124),
#  ('D_126', 0.03379100580652355),
#  ('B_30', 0.029675803765758013),
#  ('D_116', 0.025651463579537563),
#  ('D_68', 0.011178117775556953)]

# %%
test["prediction"] = prediction
submit_amex(test, 
                model="cb",
                n_cols=train.shape[1], 
                task_type=CFG.model_params['task_type'], 
                n_folds=CFG.n_folds, 
                n_seeds=len(CFG.seed_list),
                n_iter=iterations, 
                logloss_score=str(logloss_score).replace('0.', '')[:4], 
                amex_score=str(amex_metric_score).replace('0.', '')[:4],
                submit_on_kaggle=True)
# Out:
# b'Successfully submitted to American Express - Default Prediction'
